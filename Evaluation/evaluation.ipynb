# %% [markdown]
# # Final Evaluation
#
# In order to execute this notebook you need to upload the **text-detoxification.zip** as well as **both .tsv files** created in prepare_evaluation.ipynb.

# %%
# !unzip text-detoxification.zip
# !pip install -r text-detoxification/evaluation/requirements.txt

# %%
# Run Evaluation with our Data
# !python text-detoxification/evaluation/evaluate.py --submission "lora_multi.tsv" --reference "reference_multi.tsv" --batch_size 12 --fluency_batch_size 12 --device cuda
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.11/dist-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.11/dist-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# modules.json: 100% 461/461 [00:00<00:00, 2.82MB/s]
# config_sentence_transformers.json: 100% 122/122 [00:00<00:00, 814kB/s]
# README.md: 100% 2.02k/2.02k [00:00<00:00, 15.0MB/s]
# ...

# %%
# Run Evaluation with our Data
# !python text-detoxification/evaluation/evaluate.py --submission "lora_en.tsv" --reference "reference_en.tsv" --batch_size 12 --fluency_batch_size 12 --device cuda
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.11/dist-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.11/dist-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# ...

# %%
# Run Evaluation with our Data
# !python text-detoxification/evaluation/evaluate.py --submission "lora_en_tox.tsv" --reference "reference_en_tox.tsv" --batch_size 12 --fluency_batch_size 12 --device cuda
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.11/dist-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.11/dist-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# ...
